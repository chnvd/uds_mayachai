# %% [markdown]
# # BBB Speed Maps

# %%
#!pip install gtfs_functions # installation
# Import package
from gtfs_functions import Feed, map_gdf

feed = Feed("gtfs.zip", time_windows=[0, 6, 9, 15, 19, 22, 24])

routes = feed.routes
trips = feed.trips
stops = feed.stops
stop_times = feed.stop_times
shapes = feed.shapes
# Out:
# INFO:root:Reading "routes.txt".
# INFO:root:accessing trips
# INFO:root:Reading "trips.txt".
# INFO:root:Reading "trips.txt".
# INFO:root:_trips is defined in stop_times
# INFO:root:Reading "stops.txt".
# INFO:root:Reading "stop_times.txt".
# INFO:root:computing patterns
# INFO:root:Reading "shapes.txt".

# %%
segments_gdf = feed.segments
# Out:
# INFO:root:segments_df: 2149, geometry: 2149

# %%
feed.avg_speeds
# Out:
#         route_id                          route_name direction_id  \
# 0           3604  1 Main St & Santa Monica Blvd/UCLA            0
# 1           3604  1 Main St & Santa Monica Blvd/UCLA            0
# 2           3604  1 Main St & Santa Monica Blvd/UCLA            0
# 3           3604  1 Main St & Santa Monica Blvd/UCLA            0
# 4           3604  1 Main St & Santa Monica Blvd/UCLA            0
# ...          ...                                 ...          ...
# 13610  ALL_LINES                           All lines           NA
# 13611  ALL_LINES                           All lines           NA
# 13612  ALL_LINES                           All lines           NA
# 13613  ALL_LINES                           All lines           NA
# 13614  ALL_LINES                           All lines           NA
#
#        stop_sequence                                       segment_name  \
# 0                  1    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS
# 1                  1    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS
# 2                  1  SANTA MONICA EB & 6TH NS - SANTA MONICA EB & L...
# 3                  2    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS
# 4                  2    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS
# ...              ...                                                ...
# 13610             46  4TH NB & PICO FS - 4TH NB & BROADWAY NS (Downt...
# 13611             47  WASHINGTON WB & OXFORD (VEN) NS - WASHINGTON W...
# 13612             47  4TH NB & BROADWAY NS (Downtown SM Station) - S...
# 13613             48  WASHINGTON WB & WILSON NS - VIA MARINA SB & AD...
# 13614             50    7TH SB & BROADWAY NS - 7TH SB & OLYMPIC BLVD NS
#
#            window  speed_kmh  avg_route_speed_kmh  segment_max_speed_kmh  \
# 0       0:00-6:00       33.0            25.500000                   33.0
# 1       0:00-6:00       33.0            25.500000                   33.0
# 2       0:00-6:00       26.0            25.500000                   29.0
# 3       0:00-6:00       33.0            25.500000                   33.0
# 4       0:00-6:00       33.0            25.500000                   33.0
# ...           ...        ...                  ...                    ...
# 13610  9:00-15:00       17.4            21.471111                   25.0
# 13611  9:00-15:00       18.8            19.400000                   21.0
# 13612  9:00-15:00       17.9            21.420000                   25.0
# 13613  9:00-15:00       17.8            19.400000                   20.0
# 13614  9:00-15:00       15.1            20.662500                   18.0
#
#        runtime_sec                             start_stop_name  \
# 0        51.000000                         MAIN NB & MARKET NS
# 1        51.000000                         MAIN NB & MARKET NS
# 2        35.000000                    SANTA MONICA EB & 6TH NS
# 3        51.000000                         MAIN NB & MARKET NS
# 4        51.000000                         MAIN NB & MARKET NS
# ...            ...                                         ...
# 13610   160.555556                            4TH NB & PICO FS
# 13611    59.000000             WASHINGTON WB & OXFORD (VEN) NS
# 13612    50.088889  4TH NB & BROADWAY NS (Downtown SM Station)
# 13613   119.333333                   WASHINGTON WB & WILSON NS
# 13614   109.625000                        7TH SB & BROADWAY NS
#
#                                     end_stop_name   segment_id start_stop_id  \
# 0                       MAIN NB & ABBOT KINNEY NS   1305 - 361          1305
# 1                       MAIN NB & ABBOT KINNEY NS   1305 - 361          1305
# 2                    SANTA MONICA EB & LINCOLN NS      5 - 368             5
# 3                       MAIN NB & ABBOT KINNEY NS   1305 - 361          1305
# 4                       MAIN NB & ABBOT KINNEY NS   1305 - 361          1305
# ...                                           ...          ...           ...
# 13610  4TH NB & BROADWAY NS (Downtown SM Station)    283 - 431           283
# 13611                   WASHINGTON WB & WILSON NS  1577 - 1578          1577
# 13612                    SANTA MONICA EB & 4TH FS    431 - 227           431
# 13613                VIA MARINA SB & ADMIRALTY NS  1578 - 1410          1578
# 13614                    7TH SB & OLYMPIC BLVD NS  1217 - 1344          1217
#
#       end_stop_id shape_id  distance_m  \
# 0             361    26343  462.610566
# 1             361    26344  462.610566
# 2             368    26340  249.636882
# 3             361    26341  462.610566
# 4             361    26342  462.610566
# ...           ...      ...         ...
# 13610         431    26362  770.348921
# 13611        1578    26400  304.947781
# 13612         227    26362  242.116356
# 13613        1410    26400  584.741084
# 13614        1344    26362  451.785931
#
#                                                 geometry
# 0      LINESTRING (-118.47156 33.98866, -118.47160 33...
# 1      LINESTRING (-118.47156 33.98866, -118.47160 33...
# 2      LINESTRING (-118.49336 34.01792, -118.49331 34...
# 3      LINESTRING (-118.47156 33.98866, -118.47160 33...
# 4      LINESTRING (-118.47156 33.98866, -118.47160 33...
# ...                                                  ...
# 13610  LINESTRING (-118.48770 34.01002, -118.48790 34...
# 13611  LINESTRING (-118.45474 33.98663, -118.45477 33...
# 13612  LINESTRING (-118.49352 34.01500, -118.49363 34...
# 13613  LINESTRING (-118.45736 33.98496, -118.45742 33...
# 13614  LINESTRING (-118.49107 34.01764, -118.49078 34...
#
# [13615 rows x 18 columns]

# %%
speeds = feed.avg_speeds

# %%
speeds.head()
# Out:
#   route_id                          route_name direction_id  stop_sequence  \
# 0     3604  1 Main St & Santa Monica Blvd/UCLA            0              1
# 1     3604  1 Main St & Santa Monica Blvd/UCLA            0              1
# 2     3604  1 Main St & Santa Monica Blvd/UCLA            0              1
# 3     3604  1 Main St & Santa Monica Blvd/UCLA            0              2
# 4     3604  1 Main St & Santa Monica Blvd/UCLA            0              2
#
#                                         segment_name     window  speed_kmh  \
# 0    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS  0:00-6:00       33.0
# 1    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS  0:00-6:00       33.0
# 2  SANTA MONICA EB & 6TH NS - SANTA MONICA EB & L...  0:00-6:00       26.0
# 3    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS  0:00-6:00       33.0
# 4    MAIN NB & MARKET NS - MAIN NB & ABBOT KINNEY NS  0:00-6:00       33.0
#
#    avg_route_speed_kmh  segment_max_speed_kmh  runtime_sec  \
# 0                 25.5                   33.0         51.0
# 1                 25.5                   33.0         51.0
# 2                 25.5                   29.0         35.0
# 3                 25.5                   33.0         51.0
# 4                 25.5                   33.0         51.0
#
#             start_stop_name                 end_stop_name  segment_id  \
# 0       MAIN NB & MARKET NS     MAIN NB & ABBOT KINNEY NS  1305 - 361
# 1       MAIN NB & MARKET NS     MAIN NB & ABBOT KINNEY NS  1305 - 361
# 2  SANTA MONICA EB & 6TH NS  SANTA MONICA EB & LINCOLN NS     5 - 368
# 3       MAIN NB & MARKET NS     MAIN NB & ABBOT KINNEY NS  1305 - 361
# 4       MAIN NB & MARKET NS     MAIN NB & ABBOT KINNEY NS  1305 - 361
#
#   start_stop_id end_stop_id shape_id  distance_m  \
# 0          1305         361    26343  462.610566
# 1          1305         361    26344  462.610566
# 2             5         368    26340  249.636882
# 3          1305         361    26341  462.610566
# 4          1305         361    26342  462.610566
#
#                                             geometry
# 0  LINESTRING (-118.47156 33.98866, -118.47160 33...
# 1  LINESTRING (-118.47156 33.98866, -118.47160 33...
# 2  LINESTRING (-118.49336 34.01792, -118.49331 34...
# 3  LINESTRING (-118.47156 33.98866, -118.47160 33...
# 4  LINESTRING (-118.47156 33.98866, -118.47160 33...

# %%
import contextily as ctx
import matplotlib.pyplot as plt
import geopandas as gpd


# same code as before, except for plotting n_trips_scaled instead of n_trips
fig, ax = plt.subplots(figsize=(10,10))
speeds.to_crs('EPSG:3857').plot(column='speed_kmh', #needed to set the cmap to the value rather than route 
                               ax=ax, cmap='plasma', 
                               legend=True,
                               legend_kwds={'orientation': 'vertical', 'shrink': .4, 'label':"Error"}, 
                               alpha=0.7)
ctx.add_basemap(ax, zoom=12, alpha=0.5)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
speeds.speed_kmh.describe()
# Out:
# count    13615.000000
# mean        21.338986
# std          5.737337
# min          1.000000
# 25%         17.900000
# 50%         20.600000
# 75%         24.000000
# max         46.700000
# Name: speed_kmh, dtype: float64
